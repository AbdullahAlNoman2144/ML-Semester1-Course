# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahAlNoman2144/ML-Semester1-Course/blob/main/Python_class3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Python Dictionaries

# %%
dic = {}
print(type(dic))
# Out:
# <class 'dict'>

# %%
dic = {"Course":"Phitron","age":30,"numbers":{20,30,0}}
print(type(dic),"==>",dic)
# Out:
# <class 'dict'> ==> {'Course': 'Phitron', 'age': 30, 'numbers': {0, 20, 30}}

# %%
#Access
#dic_name[key]
print(dic["Course"])
print(dic.get("age"))
# Out:
# Phitron
# 30

# %% [markdown]
# ### Exanple of Mutable dictionary

# %%
dic["age"] = 26
print(dic)
keys = dic.keys()
print(keys)
# Out:
# {'Course': 'Phitron', 'age': 26, 'numbers': {0, 20, 30}, 'Name': 'Noman'}
# dict_keys(['Course', 'age', 'numbers', 'Name'])

# %%
dic["Name"] = "Noman"
# Out:
# {'Course': 'Phitron', 'age': 26, 'numbers': {0, 20, 30}, 'Name': 'Noman'}

# %%
values = dic.values()
print(values)
# Out:
# dict_values(['Phitron', 26, {0, 20, 30}, 'Noman'])

# %%
items = dic.items()
print(items)
# Out:
# dict_items([('Course', 'Phitron'), ('age', 26), ('numbers', {0, 20, 30}), ('Name', 'Noman')])

# %%
for key,value in dic.items():
  print(keys,values)
# Out:
# dict_keys(['Course', 'age', 'numbers', 'Name']) dict_values(['Phitron', 26, {0, 20, 30}, 'Noman'])
# dict_keys(['Course', 'age', 'numbers', 'Name']) dict_values(['Phitron', 26, {0, 20, 30}, 'Noman'])
# dict_keys(['Course', 'age', 'numbers', 'Name']) dict_values(['Phitron', 26, {0, 20, 30}, 'Noman'])
# dict_keys(['Course', 'age', 'numbers', 'Name']) dict_values(['Phitron', 26, {0, 20, 30}, 'Noman'])
